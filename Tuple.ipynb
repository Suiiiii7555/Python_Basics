# %%
tuple_1 = (4,8,12,16)
print(tuple_1)
print(type(tuple_1))
# Out:
# (4, 8, 12, 16)
# <class 'tuple'>

# %%
tuple_1[0] = 5
print(tuple_1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 tuple_1[0] = 5
#       2 print(tuple_1)
#
# TypeError: 'tuple' object does not support item assignment

# %%
print(help(tuple_1))

# %%
## Adding more elements to a tuple
print(tuple_1 + (20,24,28))
# Out:
# (4, 8, 12, 16, 20, 24, 28)
