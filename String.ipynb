# %%
msg = "John\'s Motor Works"
print(msg)
# Out:
# John's Motor Works

# %%
msg_2 = "def fire():\n\tprint('Maakabosuda aag')\n\tprint('Fire! Fire! Fire!')"
print(msg_2)
# Out:
# def fire():
# 	print('Maakabosuda aag')
# 	print('Fire! Fire! Fire!')
