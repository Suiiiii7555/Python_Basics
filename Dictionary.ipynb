# %%
item = {
    "Cricket - 19" : 999,
    "Forza Horizon - 5" : 1799,
    "GTA V" : 1999,
    "Cricket - 24" : 2499
}

print("The price of Games are :",item)
# Out:
# The price of Games are : {'Cricket - 19': 999, 'Forza Horizon - 5': 1799, 'GTA V': 1999, 'Cricket - 24': 2499}

# %%
books = {
    "Name" : "The Alchemist", 
    "Price": 2199,
    "Name" : "Rich Dad Poor Dad", 
    "Price": 4299,
    "Name" : "Think and Grow Rich", 
    "Price": 3399,
    "Name" : "The Power of Subconscious Mind",
    "Price": 2499
}
